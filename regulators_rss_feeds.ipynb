# %% [markdown]
# ### Get news from regulators RSS feeds

# %%
import feedparser
import pandas as pd
from bs4 import BeautifulSoup
import requests # <-- Import requests
from datetime import datetime
import time # Optional: for adding delays between requests
import ssl # <-- Import ssl for potential context modification if needed
import openai
import re

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 130)

# List of RSS feed URLs
rss_urls = [
    "https://www.bankingsupervision.europa.eu/rss/press.html",
    "https://www.bankingsupervision.europa.eu/rss/pub.html",
    "https://www.bankingsupervision.europa.eu/rss/speeches.html",
    "https://www.ecb.europa.eu/rss/blog.html",
    "https://www.ecb.europa.eu/rss/statpress.html",
    "https://www.ecb.europa.eu/rss/wppub.html",
    "https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en",
    "https://www.eba.europa.eu/news-press/news/rss.xml",
    "https://www.bis.org/doclist/rss_all_categories.rss",
    "https://www.federalreserve.gov/feeds/press_all.xml",
    "https://www.bundesbank.de/service/rss/en/633292/feed.rss",
    "https://www.bundesbank.de/service/rss/en/633306/feed.rss",
    "https://www.dnb.nl/en/rss/16451/6882",
    "https://www.bankofengland.co.uk/rss/statistics",
    "https://www.bankofengland.co.uk/rss/news",
    "https://www.bankofengland.co.uk/rss/prudential-regulation-publications",
    "https://www.bankofengland.co.uk/rss/publications",
    "https://www.rba.gov.au/rss/rss-cb-rdp.xml",
    "https://www.rba.gov.au/rss/rss-cb-speeches.xml",
    "https://www.rba.gov.au/rss/rss-cb-media-releases.xml",
    "https://www.bankofcanada.ca/content_type/technical-reports/feed/",
]

def clean_html(html_content):
    """Removes HTML tags from a string."""
    if not html_content:
        return ""
    # Use 'html.parser' for basic HTML cleaning, 'lxml' is faster if installed
    soup = BeautifulSoup(html_content, 'html.parser')
    # Get text, replace multiple spaces/newlines with a single space, strip ends
    text = soup.get_text(separator=' ', strip=True)
    return ' '.join(text.split()) # Normalize whitespace

def parse_date(entry):
    """Attempts to parse the date from various potential fields."""
    date_obj = None
    # feedparser standardizes published date into published_parsed (if possible)
    # Handles <pubDate>, <dc:date>, etc.
    if hasattr(entry, 'published_parsed') and entry.published_parsed:
        try:
            # struct_time to datetime
            date_obj = datetime(*entry.published_parsed[:6])
        except (ValueError, TypeError):
            pass # Ignore parsing errors here, try next method

    # Fallback to 'published' string if 'published_parsed' failed or missing
    if not date_obj and hasattr(entry, 'published') and entry.published:
        try:
            # Use pandas to handle various string formats robustly
            date_obj = pd.to_datetime(entry.published, errors='coerce')
        except Exception:
             pass # Ignore pandas parsing errors

    # Fallback to 'updated_parsed' or 'updated' if 'published' is missing
    if not date_obj and hasattr(entry, 'updated_parsed') and entry.updated_parsed:
         try:
             date_obj = datetime(*entry.updated_parsed[:6])
         except (ValueError, TypeError):
             pass
    if not date_obj and hasattr(entry, 'updated') and entry.updated:
        try:
            date_obj = pd.to_datetime(entry.updated, errors='coerce')
        except Exception:
             pass

    return date_obj # Returns datetime object or None

def fetch_and_parse_feeds(urls):
    """Fetches RSS feeds using requests, parses them, and returns a list of dictionaries."""
    all_items = []
    # Set a user agent to be polite to servers
    headers = {'User-Agent': 'MyRSSConsolidator/1.0 (+http://example.com)'}

    for url in urls:
        print(f"Fetching feed via requests: {url}...")
        try:
            # --- Use requests to fetch the content ---
            response = requests.get(url, headers=headers, timeout=20) # Increased timeout
            response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)

            # --- Parse the fetched content using feedparser ---
            # Pass response.content (bytes) which feedparser handles
            feed = feedparser.parse(response.content)

            # Check for feedparser-specific errors (e.g., malformed XML)
            # feedparser is generally tolerant, but good to check
            if feed.bozo:
                # Log the warning but continue if possible, as feedparser might still extract data
                print(f"  Warning: Feed XML may be malformed - {feed.bozo_exception}")

            source_name = feed.feed.get('title', url)

            if not feed.entries:
                 print(f"  No entries found in parsed feed content: {url}")
                 continue # Skip to the next URL

            print(f"  Found {len(feed.entries)} entries from '{source_name}'")

            for entry in feed.entries:
                # Extract data, providing defaults for missing fields
                title = entry.get('title', 'N/A')
                link = entry.get('link', 'N/A')
                published_date = parse_date(entry)

                # Get description (could be in 'summary' or 'description')
                # feedparser often normalizes this to entry.summary
                description_html = entry.get('summary', entry.get('description', ''))
                description_clean = clean_html(description_html)

                item_data = {
                    'title': title,
                    'link': link,
                    'published_date': published_date,
                    'description': description_clean,
                    'source_feed': source_name, # Add the source
                    'source_url': url          # Add the original URL for reference
                }
                all_items.append(item_data)

            # Add a small delay to avoid overwhelming servers
            time.sleep(0.5)

        # --- Handle potential errors ---
        except requests.exceptions.RequestException as e:
            # Handles connection errors, timeouts, HTTP errors (4xx, 5xx), etc.
            print(f"  Error fetching {url}: {e}")
        except Exception as e:
            # Catch other unexpected errors during parsing or processing
            print(f"  An unexpected error occurred processing {url}: {e}")

    return all_items

# --- Main Execution ---
if __name__ == "__main__":
    print("Starting RSS feed consolidation...")
    feed_items = fetch_and_parse_feeds(rss_urls)
    
    if not feed_items:
        print("No items were successfully fetched from any feed.")
    else:
        # Create DataFrame
        df = pd.DataFrame(feed_items)

        # Convert 'published_date' column to datetime objects (if not already)
        df['published_date'] = pd.to_datetime(df['published_date'], errors='coerce')

        df = df.sort_values(by='published_date', ascending=False, na_position='last')
        df = df.reset_index(drop=True)

        print(f"\nSuccessfully created DataFrame with {len(df)} items.")
# Out:
# Starting RSS feed consolidation...
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/press.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/pub.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/speeches.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/blog.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/statpress.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/wppub.html...
#   Warning: Feed XML may be malformed - <unknown>:7:555: not well-formed (invalid token)
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en...
#   Found 100 entries from 'EBA external communications'
# Fetching feed via requests: https://www.eba.europa.eu/news-press/news/rss.xml...
#   Found 10 entries from 'European Banking Authority'
# Fetching feed via requests: https://www.bis.org/doclist/rss_all_categories.rss...
#   Found 25 entries from 'All categories'
# Fetching feed via requests: https://www.federalreserve.gov/feeds/press_all.xml...
#   Found 20 entries from 'FRB: Press Release - All Releases'
# Fetching feed via requests: https://www.bundesbank.de/service/rss/en/633292/feed.rss...
#   Found 10 entries from 'Discussion Papers'
# Fetching feed via requests: https://www.bundesbank.de/service/rss/en/633306/feed.rss...
#   Found 10 entries from 'Latest'
# Fetching feed via requests: https://www.dnb.nl/en/rss/16451/6882...
#   Found 578 entries from 'DNB -  General news'
# Fetching feed via requests: https://www.bankofengland.co.uk/rss/statistics...
#   Found 50 entries from 'Statistics'
# Fetching feed via requests: https://www.bankofengland.co.uk/rss/news...
#   Found 50 entries from 'News'
# Fetching feed via requests: https://www.bankofengland.co.uk/rss/prudential-regulation-publications...
#   Found 50 entries from 'Prudential regulation'
# Fetching feed via requests: https://www.bankofengland.co.uk/rss/publications...
#   Found 50 entries from 'Publications'
# Fetching feed via requests: https://www.rba.gov.au/rss/rss-cb-rdp.xml...
#   Found 1 entries from 'Reserve Bank of Australia | Research Discussion Papers'
# Fetching feed via requests: https://www.rba.gov.au/rss/rss-cb-speeches.xml...
#   Found 1 entries from 'Reserve Bank of Australia | Speeches'
# Fetching feed via requests: https://www.rba.gov.au/rss/rss-cb-media-releases.xml...
#   Found 2 entries from 'Reserve Bank of Australia | Media Releases'
# Fetching feed via requests: https://www.bankofcanada.ca/content_type/technical-reports/feed/...
#   Found 10 entries from 'Technical Reports - Bank of Canada'
#
# Successfully created DataFrame with 1057 items.

# %%
# Review results
cols = ['title', 'published_date', 'source_feed', 'source_url']
df[cols].sort_values('published_date', ascending=False).drop_duplicates(subset=['published_date', 'title']).head(5)
# Out:
#                                                                                                                                title  \
# 0                                               The risk sensitivity of global liquidity flows: Heterogeneity, evolution and drivers
# 1                                                                                            Federal Treasury notes – Auction result
# 2                                                                                                              SS1/25 – Step-in Risk
# 3                                                                             PS5/25 – Identification and management of step-in risk
# 4  Consistent commercial real estate market indicators: Methodology and an application to the German office market | Discussion p...
#
#        published_date            source_feed  \
# 0 2025-04-22 12:00:00         All categories
# 1 2025-04-22 09:45:00                 Latest
# 2 2025-04-22 09:00:00  Prudential regulation
# 3 2025-04-22 09:00:00  Prudential regulation
# 4 2025-04-22 08:00:00      Discussion Papers
#
#                                                                source_url
# 0                      https://www.bis.org/doclist/rss_all_categories.rss
# 1                https://www.bundesbank.de/service/rss/en/633306/feed.rss
# 2  https://www.bankofengland.co.uk/rss/prudential-regulation-publications
# 3  https://www.bankofengland.co.uk/rss/prudential-regulation-publications
# 4                https://www.bundesbank.de/service/rss/en/633292/feed.rss

# %%
# --- Configuration ---
HEADINGS_COLUMN_NAME = 'title'
N_TOP_HEADINGS = 10

# --- Initialize OpenAI Client (Requires openai>=1.0.0) ---
client = openai.OpenAI()

# --- Function to Format Headings for OpenAI ---
def format_headings_for_prompt(dataframe: pd.DataFrame, col_name: str) -> str:
    """Formats DataFrame headings with indices for the OpenAI prompt."""
    return "\n".join([f"{index}: {row[col_name]}" for index, row in dataframe.iterrows()])

# --- Function to Call OpenAI API ---
def get_relevant_indices_from_openai(formatted_headings: str, n_results: int) -> list[int]:
    """Sends formatted headings to OpenAI and returns a list of top relevant indices."""
    system_prompt = f"""
You are an expert financial analyst specializing in credit risk.
Analyze the provided list of headlines (index: headline).
Identify headlines most relevant to credit risk and credit risk modelling. Look for words like 
credit risk risk, models, risk assessments, guidelines, fines. Also include impact from AI and Climate Change,
but in this case be very selective as these key words are common. Prioritise articles that
cover the whole system as opposed to individual banks.

Return ONLY a comma-separated list of the indices for the top {n_results} most relevant headlines.

Example output: 15, 42, 3, 88, 101, 5, 23, 9, 67, 12
"""
    completion = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": formatted_headings}
        ],
        temperature=0.1, # Low temp for deterministic output
        max_tokens=100,
    )
    raw_response = completion.choices[0].message.content.strip()

    # Parse the response - find all numbers and convert to int
    indices_str = re.findall(r'\d+', raw_response)
    indices = [int(idx) for idx in indices_str][:n_results] # Take only up to n_results
    return indices

# --- Main Execution ---
formatted_prompt_text = format_headings_for_prompt(df.head(200), HEADINGS_COLUMN_NAME)
top_indices = get_relevant_indices_from_openai(formatted_prompt_text, N_TOP_HEADINGS)

cols = ['title', 'link' , 'published_date']
df.loc[top_indices, cols].sample(N_TOP_HEADINGS).reset_index(drop=True)
# Out:
#                                                                                                                                title  \
# 0  Federal Reserve Board requests comment on a proposal to reduce the volatility of the capital requirements stemming from the Bo...
# 1                                                      Financial Stability in Focus: Artificial intelligence in the financial system
# 2                  The EBA publishes its annual assessment of banks’ internal approaches for the calculation of capital requirements
# 3                                                        ECB sanctions SEB Baltics for breaching ECB requirements on internal models
# 4                                                                                             Systemic Risk Survey Results - 2025 H1
# 5                                                                                                 Credit Conditions Survey - 2025 Q1
# 6                                                                The EBA updates list of indicators used to perform risk assessments
# 7                                            Stress testing the UK banking system: Guidance on the 2025 stress test for participants
# 8                                            Stress testing the UK banking system: Key elements of the 2025 Bank Capital stress test
# 9                                                                         Bank of England launches the 2025 Bank Capital Stress Test
#
#                                                                                                                                 link  \
# 0                                                         https://www.federalreserve.gov/newsevents/pressreleases/bcreg20250417a.htm
# 1                                                       https://www.bankofengland.co.uk/financial-stability-in-focus/2025/april-2025
# 2  https://www.eba.europa.eu/publications-and-media/press-releases/eba-publishes-its-annual-assessment-banks-internal-approaches-...
# 3                                  https://www.bankingsupervision.europa.eu//press/pr/date/2025/html/ssm.pr250418~21f6067cbc.en.html
# 4                                                                  https://www.bankofengland.co.uk/systemic-risk-survey/2025/2025-h1
# 5                                                              https://www.bankofengland.co.uk/credit-conditions-survey/2025/2025-q1
# 6          https://www.eba.europa.eu/publications-and-media/press-releases/eba-updates-list-indicators-used-perform-risk-assessments
# 7                                                      https://www.bankofengland.co.uk/stress-testing/2025/guidance-for-participants
# 8                                                      https://www.bankofengland.co.uk/stress-testing/2025/key-elements-bank-capital
# 9                                     https://www.bankofengland.co.uk/news/2025/march/boe-launches-the-2025-bank-capital-stress-test
#
#        published_date
# 0 2025-04-17 21:30:00
# 1 2025-04-09 09:30:00
# 2 2025-04-04 12:00:00
# 3 2025-04-18 16:00:00
# 4 2025-04-09 09:30:00
# 5 2025-04-17 08:30:00
# 6 2025-04-16 13:15:39
# 7 2025-03-24 10:00:00
# 8 2025-03-24 10:00:00
# 9 2025-03-24 10:00:00

# %%
df
# Out:
#                                                                                                                                   title  \
# 0                                                  The risk sensitivity of global liquidity flows: Heterogeneity, evolution and drivers
# 1                                                                                               Federal Treasury notes – Auction result
# 2                                                                                                                 SS1/25 – Step-in Risk
# 3                                                                                PS5/25 – Identification and management of step-in risk
# 4     Consistent commercial real estate market indicators: Methodology and an application to the German office market | Discussion p...
# 5                                                                              Announcement – Federal Treasury discount paper (Bubills)
# 6                                                                         Invitation to bid by auction – Reopening 10-year Federal bond
# 7              Investor sentiment and dynamic connectedness in European markets: insights from the covid-19 and Russia-Ukraine conflict
# 8                                                           ECB sanctions SEB Baltics for breaching ECB requirements on internal models
# 9     Federal Reserve Board announces approval of application by Capital One Financial Corporation to merge with Discover Financial ...
# 10                                                                    Low money market volatility benefits monetary policy transmission
# 11    Federal Reserve Board requests comment on a proposal to reduce the volatility of the capital requirements stemming from the Bo...
# 12                                                                                          Bank of England Weekly Report 16 April 2025
# 13                                                                                                        ETFs as a disciplinary device
# 14                                                                     Christine Lagarde: ECB press conference - introductory statement
# 15                                                              Junko Nakagawa: Economic activity, prices, and monetary policy in Japan
# 16                                                            Kazuo Ueda: The Bank's Semiannual Report on Currency and Monetary Control
# 17                                                                                                    Jerome H Powell: Economic outlook
# 18                                                                                  Tiff Macklem: Release of the Monetary Policy Report
# 19             Dimitar Radev: Bulgaria's forthcoming entry into the euro area is not just an important step in its European integration
# 20                                                                              Jorgovanka Tabakovi&#263;: Navigating industrial policy
# 21                 Jorgovanka Tabakovi&#263;: Gender equality in financial institutions &#8211; the case of the National Bank of Serbia
# 22                                        Darryl Chan: Opening remarks - International Conference on Generative Artificial Intelligence
# 23                                                                                                   Credit Conditions Survey - 2025 Q1
# 24                                                                                                    Bank Liabilities Survey - 2025 Q1
# 25                                                                                         Invitation to bid for Federal Treasury notes
# 26                                                                             Announcement of auction - Reopening 10-year Federal bond
# 27                                                                                         Christopher J Waller: A tale of two outlooks
# 28                                                                      Lisa D Cook: 2025 distinguished Alumna award acceptance remarks
# 29             Update on modification by consent of the Liquidity Coverage Ratio part of the PRA Rulebook – Third Country Covered Bonds
# 30                                              Federal Reserve Board announces approval of application by United Community Banks, Inc.
# 31                                                                  The EBA updates list of indicators used to perform risk assessments
# 32                                                                                            ESAs publish Joint Annual Report for 2024
# 33                                                                          Supply chain transmission of climate-related physical risks
# 34                                                                                      Reopening of two Federal bonds – Auction result
# 35                                                                            Issue of Federal Treasury notes – Announcement of auction
# 36                                                                                 Euro area monthly balance of payments: February 2025
# 37                                           Minutes of the Board's discount rate meetings on February 18, March 10, and March 19, 2025
# 38                   Agencies take action on appraisal requirements in an area affected by California wildfires and straight-line winds
# 39                 A material gender pay gap persists across EU banks and investment firms, the EBA observes in its Benchmarking Report
# 40                                           Cryptocurrencies and decentralised finance: functions and financial stability implications
# 41                                                            6-months Bills of the European Stability Mechanism (ESM) – Auction result
# 42                                                                                 Majority of Dutch people willing to use digital euro
# 43                                                 Reopening of five-year Federal notes (Bundesobligationen – “Bobls”) – Auction result
# 44                          April results of the Bank Lending Survey (BLS) in Germany | Demand continued to rise in all loan categories
# 45                         Let's speak the same language: a formally defined model to describe and compare payment system architectures
# 46                                                    Ásgeir Jónsson: Speech &#8211; 64th Annual Meeting of the Central Bank of Iceland
# 47    Petra Tschudin, Thomas Moser: Fast and available round the clock - what instant payments mean for households, companies and fi...
# 48    François Villeroy de Galhau: A European approach to simplification - avoiding three misconceptions, and suggesting concrete mi...
# 49                                           Claudia Buch: European banking integration - harnessing the benefits, containing the risks
# 50                                                      Swaminathan J: Shared vision, shared responsibility &#8211; strenghtening NBFCs
# 51                                          Fabio Panetta: Opening of The Adventure of Money "From Gold to the Digital Euro" exhibition
# 52                                                                                                     John C Williams: Uncertain times
# 53                                                                           Michele Bullock: Women's economic empowerment in Australia
# 54                                Klaas Knot: Stating the obvious - a central bankers perspective on resilience in times of uncertainty
# 55                                                                                    Eighth edition of the Regulatory Initiatives Grid
# 56                                             Stating the obvious: a central bankers perspective on resilience in times of uncertainty
# 57                                                                                               Claudia Buch: Interview with Bloomberg
# 58                                                                              List of supervised entities – Cut-off date 1 March 2025
# 59                            Sharon Donnery: Resilience, risk and regulation: anchoring stability in a rules-based international order
# 60                            Sharon Donnery: Resilience, risk and regulation: anchoring stability in a rules-based international order
# 61                                                                                           Bank of England Weekly Report 9 April 2025
# 62                                                                                    Digital pound experiment report: Offline payments
# 63                                                                                 Minutes of the CBDC Engagement Forum - November 2024
# 64                                                                                 Design note – Intermediary roles and scheme rulebook
# 65                                            Claudia Buch: European banking integration: harnessing the benefits, containing the risks
# 66                                            Claudia Buch: European banking integration: harnessing the benefits, containing the risks
# 67                                                          Asset Purchase Facility: Gilt Sales Amendment - Market Notice 10 April 2025
# 68                                                                                            Women's Economic Empowerment in Australia
# 69                                                                                Prudential Regulation Authority Business Plan 2025/26
# 70                                                                      CP8/25 – Regulated fees and levies: Rates proposals for 2025/26
# 71                                                                      Minutes of the Federal Open Market Committee, March 18–19, 2025
# 72                                                                                       Financial Policy Committee Record – April 2025
# 73                                                                                               Systemic Risk Survey Results - 2025 H1
# 74                                                        Financial Stability in Focus: Artificial intelligence in the financial system
# 75                                                                         Significant risk transfer financing: Prudential expectations
# 76                                                                            Do central bank reforms lead to more monetary discipline?
# 77                                                                                Anneli Tuominen: Banks in a changing global landscape
# 78                          Federal Reserve Board announces termination of enforcement action with former employee of The Marathon Bank
# 79                                       Patrick Montagner: Cross-border banking in the EU: from national silos to an integrated market
# 80                                                 Patrick Montagner: Balancing diversity and stability in European banking supervision
# 81                                                 Response to the discussion paper on reviewing access to RTGS accounts for settlement
# 82                                              EBA updates list of institutions involved in the 2025 supervisory benchmarking exercise
# 83                                         Conference on Globalisation and geo-economic fragmentation: follow via livestream on 9 April
# 84                                                           PRA launches consultation to help insurers accelerate investment in the UK
# 85                                                                                  CP7/25 – Matching Adjustment Investment Accelerator
# 86                                                             Significant growth in securitisations in 2024 after years of contraction
# 87                                           Boundedly Rational Expectations and the Optimality of Flexible Average Inflation Targeting
# 278                                                                                                PRA Regulatory Digest - January 2025
# 279                                                                                                Europe has strengths it can build on
# 280                                                                   From Frankfurt with love: 14 years on the ECB’s Governing Council
# 281                                                                                         Credit union quarterly statistics - 2024 Q3
# 282   Bank of England statement on the European Commission equivalence decision on the UK’s legal and supervisory framework for cent...
# 283                                                                                       Bank of England Weekly Report 29 January 2025
# 284                                                             Fine for de Volksbank N.V. for deficient anti-money laundering controls
# 285                                           Administrative fine for de Volksbank N.V. for failure to ensure sound business operations
# 286                                                               Dutch households keep saving: more than €600 billion in bank accounts
# 287                                                                                 Fines totalling €20 million imposed on de Volksbank
# 288                                                                                           PRA Climate Change Adaptation Report 2025
# 289                                                                                                    Money and Credit - December 2024
# 290                                                                                            Effective interest rates - December 2024
# 291                                                                                             Payments statistics: first half of 2024
# 292                                                                               Minutes: CBDC Academic Advisory Group – December 2024
# 293                                                                        Minutes of the CBDC Academic Advisory Group - September 2024
# 294                                                                               Monetary developments in the euro area: December 2024
# 295                                                     Bank of England opens New Contingent Non-Bank Lending Facility for applications
# 296                                                                Contingent NBFI Repo Facility (CNRF) – Market Notice 28 January 2025
# 297                                                                              Average funding ratio of Dutch pension sector declined
# 298                                        Euro area economic and financial developments by institutional sector: third quarter of 2024
# 299                                                                       Andrea Enria appointed to the Prudential Regulation Committee
# 300                                                                                                    Capital Issuance - December 2024
# 301                                Chancellor appoints David Soanes and Niamh Moloney as members of the Prudential Regulation Committee
# 302                                                                         Liquidity, monetary policy and the commodity futures market
# 303                                                                         Dealers, information and liquidity provision in safe assets
# 304                                                                                         Bouncing back: how mothballing curbs prices
# 305                        Trade dynamics under geopolitical risk | Discussion paper 03/2025: Makram Khalil, David Osten, Felix Strobel
# 306                                                                                       Bank of England Weekly Report 22 January 2025
# 307   Cap and Trade versus tradable performance standard: A comparison for Europe and China | Discussion paper 02/2025: Peter Burgol...
# 308                                                                                     ECB has stopped reinvestments in maturing bonds
# 309                                     Letter from Charlotte Gerken  and Laura Wallis ‘UK Deposit Takers Supervision: 2025 priorities’
# 310                                    Letter from Rebecca Jackson and Alison Scott  ‘International banks Supervision: 2025 priorities’
# 311                                                     Cash remains a key payment method in Europe, but its share continues to decline
# 312                                                                                  Relative price of services recovers after pandemic
# 313                    Patrick Montagner: Interview with Forvis Mazars on the ECB’s supervisory priorities and 2025 EU-wide stress test
# 314                                         List of banks not included in the EBA sample that take part in the parallel ECB stress test
# 315                                   Luis de Guindos, Frank Elderson: Why prudent projections are the backbone of sound stress testing
# 316                                                                                                    PRA letter to the Prime Minister
# 317                                                                                              DNB and ATI end cooperation on Bonaire
# 318                                                              The anatomy of a shock to residential real estate: the role of lending
# 319                                          The Bank of England’s statutory monetary policy objectives: a historical and legal account
# 320                                                              Bank of England launches economic education quiz with £1000 cash prize
# 321   Stuck in a marriage: Labor market shocks, divorce and intra-household reallocation | Discussion paper 01/2025: Wataru Kureishi...
# 322                                                                        The PRA announces a delay to the implementation of Basel 3.1
# 323   The Bank of England and the Commodity Futures Trading Commission input into report on initial margin transparency and responsi...
# 324                                                                            Exploring an uncertain future with the help of scenarios
