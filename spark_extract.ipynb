# %%
import os
import csv
import zipfile
import pandas as pd
from pyspark.sql import SparkSession
from tqdm import tqdm

# 1) Create or get an existing SparkSession
spark = SparkSession.builder.appName("GetFannieMaeDataset").getOrCreate()

# 2) Optional: configure Pandas for nicer display
pd.set_option("display.max_columns", None)

# 3) Define the columns we want to apply as headers
headers = [
    "POOL_ID",
    "LOAN_ID",
    "ACT_PERIOD",
    "CHANNEL",
    "SELLER",
    "SERVICER",
    "MASTER_SERVICER",
    "ORIG_RATE",
    "CURR_RATE",
    "ORIG_UPB",
    "ISSUANCE_UPB",
    "CURRENT_UPB",
    "ORIG_TERM",
    "ORIG_DATE",
    "FIRST_PAY",
    "LOAN_AGE",
    "REM_MONTHS",
    "ADJ_REM_MONTHS",
    "MATR_DT",
    "OLTV",
    "OCLTV",
    "NUM_BO",
    "DTI",
    "CSCORE_B",
    "CSCORE_C",
    "FIRST_FLAG",
    "PURPOSE",
    "PROP",
    "NO_UNITS",
    "OCC_STAT",
    "STATE",
    "MSA",
    "ZIP",
    "MI_PCT",
    "PRODUCT",
    "PPMT_FLG",
    "IO",
    "FIRST_PAY_IO",
    "MNTHS_TO_AMTZ_IO",
    "DLQ_STATUS",
    "PMT_HISTORY",
    "MOD_FLAG",
    "MI_CANCEL_FLAG",
    "Zero_Bal_Code",
    "ZB_DTE",
    "LAST_UPB",
    "RPRCH_DTE",
    "CURR_SCHD_PRNCPL",
    "TOT_SCHD_PRNCPL",
    "UNSCHD_PRNCPL_CURR",
    "LAST_PAID_INSTALLMENT_DATE",
    "FORECLOSURE_DATE",
    "DISPOSITION_DATE",
    "FORECLOSURE_COSTS",
    "PROPERTY_PRESERVATION_AND_REPAIR_COSTS",
    "ASSET_RECOVERY_COSTS",
    "MISCELLANEOUS_HOLDING_EXPENSES_AND_CREDITS",
    "ASSOCIATED_TAXES_FOR_HOLDING_PROPERTY",
    "NET_SALES_PROCEEDS",
    "CREDIT_ENHANCEMENT_PROCEEDS",
    "REPURCHASES_MAKE_WHOLE_PROCEEDS",
    "OTHER_FORECLOSURE_PROCEEDS",
    "NON_INTEREST_BEARING_UPB",
    "PRINCIPAL_FORGIVENESS_AMOUNT",
    "ORIGINAL_LIST_START_DATE",
    "ORIGINAL_LIST_PRICE",
    "CURRENT_LIST_START_DATE",
    "CURRENT_LIST_PRICE",
    "ISSUE_SCOREB",
    "ISSUE_SCOREC",
    "CURR_SCOREB",
    "CURR_SCOREC",
    "MI_TYPE",
    "SERV_IND",
    "CURRENT_PERIOD_MODIFICATION_LOSS_AMOUNT",
    "CUMULATIVE_MODIFICATION_LOSS_AMOUNT",
    "CURRENT_PERIOD_CREDIT_EVENT_NET_GAIN_OR_LOSS",
    "CUMULATIVE_CREDIT_EVENT_NET_GAIN_OR_LOSS",
    "HOMEREADY_PROGRAM_INDICATOR",
    "FORECLOSURE_PRINCIPAL_WRITE_OFF_AMOUNT",
    "RELOCATION_MORTGAGE_INDICATOR",
    "ZERO_BALANCE_CODE_CHANGE_DATE",
    "LOAN_HOLDBACK_INDICATOR",
    "LOAN_HOLDBACK_EFFECTIVE_DATE",
    "DELINQUENT_ACCRUED_INTEREST",
    "PROPERTY_INSPECTION_WAIVER_INDICATOR",
    "HIGH_BALANCE_LOAN_INDICATOR",
    "ARM_5_YR_INDICATOR",
    "ARM_PRODUCT_TYPE",
    "MONTHS_UNTIL_FIRST_PAYMENT_RESET",
    "MONTHS_BETWEEN_SUBSEQUENT_PAYMENT_RESET",
    "INTEREST_RATE_CHANGE_DATE",
    "PAYMENT_CHANGE_DATE",
    "ARM_INDEX",
    "ARM_CAP_STRUCTURE",
    "INITIAL_INTEREST_RATE_CAP",
    "PERIODIC_INTEREST_RATE_CAP",
    "LIFETIME_INTEREST_RATE_CAP",
    "MARGIN",
    "BALLOON_INDICATOR",
    "PLAN_NUMBER",
    "FORBEARANCE_INDICATOR",
    "HIGH_LOAN_TO_VALUE_HLTV_REFINANCE_OPTION_INDICATOR",
    "DEAL_NAME",
    "RE_PROCS_FLAG",
    "ADR_TYPE",
    "ADR_COUNT",
    "ADR_UPB",
]

# 4) Absolute path to the single ZIP file
zip_path = r"D:\mae_files\Performance_All.zip"

# 5) Where to extract the CSV files
extract_folder = r"D:\kala"

# 6) Final Excel output path
output_excel = r"D:\kala\selected_fm_rows.xlsx"

# This list will hold the sampled data from each CSV
sampled_frames = []

# 8) Build a schema with all columns as StringType
# schema = StructType([StructField(col, StringType(), True) for col in headers])

# 9) Open the single ZIP file
with zipfile.ZipFile(zip_path, 'r') as zf:
    # List all files in this ZIP
    all_files = zf.namelist()
    # We only want CSV files that end with "Q4.csv"
    q4_files = [f for f in all_files if f.endswith("2Q4.csv")]
    
    # Iterate over these Q4 files with a progress bar
    for q4 in tqdm(q4_files, desc="Processing Q4 CSVs"):
        # Extract CSV to extract_folder
        extracted_path = zf.extract(q4, extract_folder)
        
        # Read into Spark
        spark_df = (
            spark.read
            .csv(extracted_path, sep='|', header=False, inferSchema=True)
            # .csv(extracted_path, sep='|', header=False, schema=schema)
        )
        # Apply our headers
        spark_df = spark_df.toDF(*headers)
        
        # Take a sample (adjust fraction as needed)
        sampled_spark = spark_df.sample(fraction=0.01, seed=42)
        
        # Convert Spark DataFrame to pandas
        sampled_pd = sampled_spark.toPandas()
        
        # Append to the list
        sampled_frames.append(sampled_pd)
        
        # Delete the extracted CSV to save space
        os.remove(extracted_path)

# 8) Concatenate all sampled dataframes
if sampled_frames:
    final_df = pd.concat(sampled_frames, ignore_index=True)
    
    # 9) Export the result to Excel
    final_df.head(100_000).to_excel(output_excel, index=False)
    print(f"Final concatenated sample saved to: {output_excel}")
else:
    print("No Q4.csv files found in the ZIP archive.")
# Out:
# Processing Q4 CSVs: 100%|███████████████████████████████████████████████████████████████| 3/3 [08:34<00:00, 171.52s/it]
# C:\Users\Watson\AppData\Local\Temp\ipykernel_10044\3515848291.py:176: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat(sampled_frames, ignore_index=True)
# Final concatenated sample saved to: D:\kala\selected_fm_rows.xlsx

# %%
final_df.head()
# Out:
#   POOL_ID       LOAN_ID  ACT_PERIOD CHANNEL  \
# 0    None  100003164216       62016       R
# 1    None  100008120784      102012       R
# 2    None  100008218145      122012       C
# 3    None  100013477387      122012       C
# 4    None  100019487094       32020       C
#
#                                       SELLER  \
# 0                                      Other
# 1                     Wells Fargo Bank, N.A.
# 2       Flagstar Capital Markets Corporation
# 3  Jpmorgan Chase Bank, National Association
# 4                                      Other
#
#                                SERVICER MASTER_SERVICER  ORIG_RATE  CURR_RATE  \
# 0                                 Other            None      3.625      3.625
# 1                Wells Fargo Bank, N.A.            None      3.375      3.375
# 2  Flagstar Capital Markets Corporation            None      3.625      3.625
# 3              Jp Morgan Chase Bank, Na            None      3.375      3.375
# 4                                 Other            None      3.625      3.625
#
#    ORIG_UPB ISSUANCE_UPB  CURRENT_UPB  ORIG_TERM  ORIG_DATE  FIRST_PAY  \
# 0  478000.0         None    445095.54        360     112012      12013
# 1  344000.0         None         0.00        180     122011      32012
# 2  403000.0         None         0.00        360      92012     112012
# 3  136000.0         None         0.00        180      82012     102012
# 4   65000.0         None     37589.85        180     102012     122012
#
#    LOAN_AGE  REM_MONTHS  ADJ_REM_MONTHS   MATR_DT  OLTV  OCLTV  NUM_BO   DTI  \
# 0      42.0       318.0           318.0  122042.0    68   68.0     2.0  25.0
# 1       8.0       172.0           170.0   22027.0    56   68.0     1.0  14.0
# 2       2.0       358.0           357.0  102042.0    54   61.0     2.0  33.0
# 3       3.0       177.0           176.0   92027.0    54   54.0     1.0  29.0
# 4      88.0        92.0            92.0  112027.0    67   67.0     1.0  42.0
#
#    CSCORE_B  CSCORE_C FIRST_FLAG PURPOSE PROP  NO_UNITS OCC_STAT STATE    MSA  \
# 0     763.0     742.0          N       R   PU         1        P    CA  31080
# 1     793.0       NaN          N       R   SF         1        P    NY  35620
# 2     749.0     747.0          N       R   SF         1        P    WA  42660
# 3     810.0       NaN          N       R   PU         1        P    IL  16980
# 4     674.0       NaN          N       C   SF         1        P    MS  25060
#
#    ZIP  MI_PCT PRODUCT PPMT_FLG IO FIRST_PAY_IO MNTHS_TO_AMTZ_IO DLQ_STATUS  \
# 0  913     NaN     FRM        N  N         None             None         00
# 1  109     NaN     FRM        N  N         None             None         00
# 2  981     NaN     FRM        N  N         None             None         00
# 3  605     NaN     FRM        N  N         None             None         00
# 4  395     NaN     FRM        N  N         None             None         00
#
#   PMT_HISTORY MOD_FLAG MI_CANCEL_FLAG  Zero_Bal_Code  ZB_DTE  LAST_UPB  \
# 0        None        N           None            NaN     NaN       NaN
# 1        None        N           None            NaN     NaN       NaN
# 2        None        N           None            NaN     NaN       NaN
# 3        None        N           None            NaN     NaN       NaN
# 4        None        N           None            NaN     NaN       NaN
#
#   RPRCH_DTE CURR_SCHD_PRNCPL  TOT_SCHD_PRNCPL UNSCHD_PRNCPL_CURR  \
# 0      None             None              NaN               None
# 1      None             None              NaN               None
# 2      None             None              NaN               None
# 3      None             None              NaN               None
# 4      None             None              NaN               None
#
#    LAST_PAID_INSTALLMENT_DATE  FORECLOSURE_DATE  DISPOSITION_DATE  \
# 0                         NaN               NaN               NaN
# 1                         NaN               NaN               NaN
# 2                         NaN               NaN               NaN
# 3                         NaN               NaN               NaN
# 4                         NaN               NaN               NaN
#
#    FORECLOSURE_COSTS  PROPERTY_PRESERVATION_AND_REPAIR_COSTS  \
# 0                NaN                                     NaN
# 1                NaN                                     NaN
# 2                NaN                                     NaN
# 3                NaN                                     NaN
# 4                NaN                                     NaN
#
#    ASSET_RECOVERY_COSTS  MISCELLANEOUS_HOLDING_EXPENSES_AND_CREDITS  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
#
#    ASSOCIATED_TAXES_FOR_HOLDING_PROPERTY  NET_SALES_PROCEEDS  \
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    NaN                 NaN
#
#    CREDIT_ENHANCEMENT_PROCEEDS  REPURCHASES_MAKE_WHOLE_PROCEEDS  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
#
#    OTHER_FORECLOSURE_PROCEEDS  NON_INTEREST_BEARING_UPB  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    PRINCIPAL_FORGIVENESS_AMOUNT ORIGINAL_LIST_START_DATE ORIGINAL_LIST_PRICE  \
# 0                           NaN                     None                None
# 1                           NaN                     None                None
# 2                           NaN                     None                None
# 3                           NaN                     None                None
# 4                           NaN                     None                None
#
#   CURRENT_LIST_START_DATE CURRENT_LIST_PRICE ISSUE_SCOREB ISSUE_SCOREC  \
# 0                    None               None         None         None
# 1                    None               None         None         None
# 2                    None               None         None         None
# 3                    None               None         None         None
# 4                    None               None         None         None
#
#   CURR_SCOREB CURR_SCOREC  MI_TYPE SERV_IND  \
# 0        None        None      NaN        N
# 1        None        None      NaN        N
# 2        None        None      NaN        N
# 3        None        None      NaN        N
# 4        None        None      NaN        N
#
#   CURRENT_PERIOD_MODIFICATION_LOSS_AMOUNT CUMULATIVE_MODIFICATION_LOSS_AMOUNT  \
# 0                                    None                                None
# 1                                    None                                None
# 2                                    None                                None
# 3                                    None                                None
# 4                                    None                                None
#
#   CURRENT_PERIOD_CREDIT_EVENT_NET_GAIN_OR_LOSS  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
#
#   CUMULATIVE_CREDIT_EVENT_NET_GAIN_OR_LOSS HOMEREADY_PROGRAM_INDICATOR  \
# 0                                     None                           7
# 1                                     None                           7
# 2                                     None                           7
# 3                                     None                           7
# 4                                     None                           7
#
#    FORECLOSURE_PRINCIPAL_WRITE_OFF_AMOUNT RELOCATION_MORTGAGE_INDICATOR  \
# 0                                     NaN                             N
# 1                                     NaN                             N
# 2                                     NaN                             N
# 3                                     NaN                             N
# 4                                     NaN                             N
#
#   ZERO_BALANCE_CODE_CHANGE_DATE LOAN_HOLDBACK_INDICATOR  \
# 0                          None                    None
# 1                          None                    None
# 2                          None                    None
# 3                          None                    None
# 4                          None                    None
#
#   LOAN_HOLDBACK_EFFECTIVE_DATE DELINQUENT_ACCRUED_INTEREST  \
# 0                         None                        None
# 1                         None                        None
# 2                         None                        None
# 3                         None                        None
# 4                         None                        None
#
#   PROPERTY_INSPECTION_WAIVER_INDICATOR HIGH_BALANCE_LOAN_INDICATOR  \
# 0                                 None                           Y
# 1                                 None                           N
# 2                                 None                           N
# 3                                 None                           N
# 4                                 None                           N
#
#   ARM_5_YR_INDICATOR ARM_PRODUCT_TYPE MONTHS_UNTIL_FIRST_PAYMENT_RESET  \
# 0               None             None                             None
# 1               None             None                             None
# 2               None             None                             None
# 3               None             None                             None
# 4               None             None                             None
#
#   MONTHS_BETWEEN_SUBSEQUENT_PAYMENT_RESET INTEREST_RATE_CHANGE_DATE  \
# 0                                    None                      None
# 1                                    None                      None
# 2                                    None                      None
# 3                                    None                      None
# 4                                    None                      None
#
#   PAYMENT_CHANGE_DATE ARM_INDEX ARM_CAP_STRUCTURE INITIAL_INTEREST_RATE_CAP  \
# 0                None      None              None                      None
# 1                None      None              None                      None
# 2                None      None              None                      None
# 3                None      None              None                      None
# 4                None      None              None                      None
#
#   PERIODIC_INTEREST_RATE_CAP LIFETIME_INTEREST_RATE_CAP MARGIN  \
# 0                       None                       None   None
# 1                       None                       None   None
# 2                       None                       None   None
# 3                       None                       None   None
# 4                       None                       None   None
#
#   BALLOON_INDICATOR PLAN_NUMBER FORBEARANCE_INDICATOR  \
# 0              None        None                  None
# 1              None        None                  None
# 2              None        None                  None
# 3              None        None                  None
# 4              None        None                  None
#
#   HIGH_LOAN_TO_VALUE_HLTV_REFINANCE_OPTION_INDICATOR DEAL_NAME RE_PROCS_FLAG  \
# 0                                                  N      None          None
# 1                                                  N      None          None
# 2                                                  N      None          None
# 3                                                  N      None          None
# 4                                                  N      None          None
#
#   ADR_TYPE  ADR_COUNT  ADR_UPB
# 0     None        NaN      NaN
# 1     None        NaN      NaN
# 2     None        NaN      NaN
# 3     None        NaN      NaN
# 4     None        NaN      NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347114 entries, 0 to 1347113
# Columns: 108 entries, POOL_ID to ADR_UPB
# dtypes: float64(36), int32(8), int64(1), object(63)
# memory usage: 1.0+ GB
