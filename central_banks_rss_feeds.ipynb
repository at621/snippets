# %%
import feedparser
import pandas as pd
from bs4 import BeautifulSoup
import requests # <-- Import requests
from datetime import datetime
import time # Optional: for adding delays between requests
import ssl # <-- Import ssl for potential context modification if needed

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# List of RSS feed URLs
rss_urls = [
    "https://www.bankingsupervision.europa.eu/rss/press.html",
    "https://www.bankingsupervision.europa.eu/rss/pub.html",
    "https://www.bankingsupervision.europa.eu/rss/speeches.html",
    "https://www.ecb.europa.eu/rss/blog.html",
    "https://www.ecb.europa.eu/rss/statpress.html",
    "https://www.ecb.europa.eu/rss/wppub.html",
    "https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en",
    "https://www.eba.europa.eu/news-press/news/rss.xml",
    "https://www.bis.org/doclist/rss_all_categories.rss",
    "https://www.federalreserve.gov/feeds/press_all.xml",
]

def clean_html(html_content):
    """Removes HTML tags from a string."""
    if not html_content:
        return ""
    # Use 'html.parser' for basic HTML cleaning, 'lxml' is faster if installed
    soup = BeautifulSoup(html_content, 'html.parser')
    # Get text, replace multiple spaces/newlines with a single space, strip ends
    text = soup.get_text(separator=' ', strip=True)
    return ' '.join(text.split()) # Normalize whitespace

def parse_date(entry):
    """Attempts to parse the date from various potential fields."""
    date_obj = None
    # feedparser standardizes published date into published_parsed (if possible)
    # Handles <pubDate>, <dc:date>, etc.
    if hasattr(entry, 'published_parsed') and entry.published_parsed:
        try:
            # struct_time to datetime
            date_obj = datetime(*entry.published_parsed[:6])
        except (ValueError, TypeError):
            pass # Ignore parsing errors here, try next method

    # Fallback to 'published' string if 'published_parsed' failed or missing
    if not date_obj and hasattr(entry, 'published') and entry.published:
        try:
            # Use pandas to handle various string formats robustly
            date_obj = pd.to_datetime(entry.published, errors='coerce')
        except Exception:
             pass # Ignore pandas parsing errors

    # Fallback to 'updated_parsed' or 'updated' if 'published' is missing
    if not date_obj and hasattr(entry, 'updated_parsed') and entry.updated_parsed:
         try:
             date_obj = datetime(*entry.updated_parsed[:6])
         except (ValueError, TypeError):
             pass
    if not date_obj and hasattr(entry, 'updated') and entry.updated:
        try:
            date_obj = pd.to_datetime(entry.updated, errors='coerce')
        except Exception:
             pass

    return date_obj # Returns datetime object or None

def fetch_and_parse_feeds(urls):
    """Fetches RSS feeds using requests, parses them, and returns a list of dictionaries."""
    all_items = []
    # Set a user agent to be polite to servers
    headers = {'User-Agent': 'MyRSSConsolidator/1.0 (+http://example.com)'}

    for url in urls:
        print(f"Fetching feed via requests: {url}...")
        try:
            # --- Use requests to fetch the content ---
            response = requests.get(url, headers=headers, timeout=20) # Increased timeout
            response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)

            # --- Parse the fetched content using feedparser ---
            # Pass response.content (bytes) which feedparser handles
            feed = feedparser.parse(response.content)

            # Check for feedparser-specific errors (e.g., malformed XML)
            # feedparser is generally tolerant, but good to check
            if feed.bozo:
                # Log the warning but continue if possible, as feedparser might still extract data
                print(f"  Warning: Feed XML may be malformed - {feed.bozo_exception}")

            source_name = feed.feed.get('title', url)

            if not feed.entries:
                 print(f"  No entries found in parsed feed content: {url}")
                 continue # Skip to the next URL

            print(f"  Found {len(feed.entries)} entries from '{source_name}'")

            for entry in feed.entries:
                # Extract data, providing defaults for missing fields
                title = entry.get('title', 'N/A')
                link = entry.get('link', 'N/A')
                published_date = parse_date(entry)

                # Get description (could be in 'summary' or 'description')
                # feedparser often normalizes this to entry.summary
                description_html = entry.get('summary', entry.get('description', ''))
                description_clean = clean_html(description_html)

                item_data = {
                    'title': title,
                    'link': link,
                    'published_date': published_date,
                    'description': description_clean,
                    'source_feed': source_name, # Add the source
                    'source_url': url          # Add the original URL for reference
                }
                all_items.append(item_data)

            # Add a small delay to avoid overwhelming servers
            time.sleep(0.5)

        # --- Handle potential errors ---
        except requests.exceptions.RequestException as e:
            # Handles connection errors, timeouts, HTTP errors (4xx, 5xx), etc.
            print(f"  Error fetching {url}: {e}")
        except Exception as e:
            # Catch other unexpected errors during parsing or processing
            print(f"  An unexpected error occurred processing {url}: {e}")

    return all_items

# --- Main Execution ---
if __name__ == "__main__":
    print("Starting RSS feed consolidation...")
    feed_items = fetch_and_parse_feeds(rss_urls)
    
    if not feed_items:
        print("No items were successfully fetched from any feed.")
    else:
        # Create DataFrame
        df = pd.DataFrame(feed_items)

        # Convert 'published_date' column to datetime objects (if not already)
        df['published_date'] = pd.to_datetime(df['published_date'], errors='coerce')

        df = df.sort_values(by='published_date', ascending=False, na_position='last')
        df = df.reset_index(drop=True)

        print(f"\nSuccessfully created DataFrame with {len(df)} items.")
# Out:
# Starting RSS feed consolidation...
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/press.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/pub.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.bankingsupervision.europa.eu/rss/speeches.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/blog.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/statpress.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://www.ecb.europa.eu/rss/wppub.html...
#   Found 15 entries from 'ECB - European Central Bank'
# Fetching feed via requests: https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en...
#   Found 100 entries from 'EBA external communications'
# Fetching feed via requests: https://www.eba.europa.eu/news-press/news/rss.xml...
#   Found 10 entries from 'European Banking Authority'
# Fetching feed via requests: https://www.bis.org/doclist/rss_all_categories.rss...
#   Found 25 entries from 'All categories'
# Fetching feed via requests: https://www.federalreserve.gov/feeds/press_all.xml...
#   Found 20 entries from 'FRB: Press Release - All Releases'
#
# Successfully created DataFrame with 245 items.

# %%
# Review results
cols = ['title', 'published_date', 'source_feed', 'source_url']
df[cols].sort_values('published_date', ascending=False).drop_duplicates(subset=['published_date', 'title']).head(50)
# Out:
#                                                                                                                     title  \
# 0                                                    How accurately do consumers report their debts in household surveys?
# 1                                                                                  Claudia Buch: Interview with Bloomberg
# 2                                                                 List of supervised entities – Cut-off date 1 March 2025
# 3               Sharon Donnery: Resilience, risk and regulation: anchoring stability in a rules-based international order
# 5                                             Macroprudential and  monetary policy tightening: more than a double whammy?
# 6                               Claudia Buch: European banking integration: harnessing the benefits, containing the risks
# 8                                                         Leveraging tokenisation for payments and financial transactions
# 9                                                         Minutes of the Federal Open Market Committee, March 18–19, 2025
# 10                           Act early or pay later: the role of qualitative measures in effective supervisory frameworks
# 11                           Jan Frait: Monetary policy analysis at the crossroads - insights from central banks' reviews
# 12                                                              Do central bank reforms lead to more monetary discipline?
# 13                          Eva Zamrazilová: The role of macroeconomic models in the forecasting process - survey results
# 14                              Mary-Elizabeth McMunn: Shocks and shifts - regulation and supervision in a changing world
# 15                              Piero Cipollone: Empowering Europe - boosting strategic autonomy through the digital euro
# 16                               Olli Rehn: In science we trust? European enlightenment in the harsh world of geopolitics
# 17                                        Abdul Rasheed Ghaffour: Launch of the Cambodia-Malaysia cross-border QR phase 2
# 18                                      Ida Wolden Bache: Cooperation and independence - Norges Bank in a turbulent world
# 19                            Chiara Scotti: Financial and tax regulation for the digital era - charting the path forward
# 20                              Madelena Mohamed: Supply chain resilience - insights into greening value chains for ASEAN
# 21                                                                                Michael S Barr: AI, fintechs, and banks
# 22                                                  Soledad Núñez: The Spanish banking system and the challenges it faces
# 23                                                                   Lisa D Cook: The economic outlook and path of policy
# 24                                                                  Anneli Tuominen: Banks in a changing global landscape
# 25                                   Patrick Montagner: Balancing diversity and stability in European banking supervision
# 26            Federal Reserve Board announces termination of enforcement action with former employee of The Marathon Bank
# 27                         Patrick Montagner: Cross-border banking in the EU: from national silos to an integrated market
# 28                                EBA updates list of institutions involved in the 2025 supervisory benchmarking exercise
# 29                                                     The disciplining effect of bank supervision: evidence from SupTech
# 30                                                                                        Technology & Innovation Advisor
# 31                       The EBA is finalising its draft RTS on the criteria to appoint a central contact point for CASPs
# 32                 The EBA’s Consumer Trends Report 2024/25 finds that de-risking remains a key issue facing EU consumers
# 33                                                   ESMA asks supervisors to consider ML/TF risks when authorising CASPs
# 34                                                            EBA and ESMA report on recent developments in crypto-assets
# 35                                                                                EBA hosts a workshop on AML/CFT SupTech
# 36                                                                                       EBA Peer review on tax integrity
# 37                                         The Restrictive Measures Guidelines have been translated into all EU languages
# 38                                                                The new crypto-asset framework is now fully implemented
# 39                            The EBA supports the smooth transition to the new legal and institutional AML/CFT framework
# 40  The EBA  consults on new rules related to the anti-money laundering and countering the financing of terrorism package
# 41                          EBA publishes its Peer Review on the performance of stress tests by Deposit Guarantee Schemes
# 42                    Affordable housing, unaffordable credit? Concentration and high-cost lending for manufactured homes
# 43                                                     Worrying about war: geopolitical risks weigh on consumer sentiment
# 44                                                                Luis de Guindos: Financial stability in uncertain times
# 45                                       Sanjay Malhotra: Welcome address - 90th anniversary of the Reserve Bank of India
# 46                                                                                      Jerome H Powell: Economic outlook
# 47                                                            Christine Lagarde: A "European moment" in an inverted world
# 48                                                                      Christine Lagarde: The transformative power of AI
# 49                                   Abdul Rasheed Ghaffour: Unlocking opportunities to advance ASEAN climate initiatives
# 50      The EBA publishes its annual assessment of banks’ internal approaches for the calculation of capital requirements
# 51                                     Households and non-financial corporations in the euro area: fourth quarter of 2024
#
#         published_date                        source_feed  \
# 0  2025-04-11 12:00:00                     All categories
# 1  2025-04-11 11:00:00        ECB - European Central Bank
# 2  2025-04-11 08:00:00        ECB - European Central Bank
# 3  2025-04-10 15:10:00        ECB - European Central Bank
# 5  2025-04-10 12:00:00                     All categories
# 6  2025-04-10 12:00:00        ECB - European Central Bank
# 8  2025-04-10 08:34:00                     All categories
# 9  2025-04-09 18:00:00  FRB: Press Release - All Releases
# 10 2025-04-09 13:02:00                     All categories
# 11 2025-04-09 11:52:00                     All categories
# 12 2025-04-09 09:00:00        ECB - European Central Bank
# 13 2025-04-09 08:55:00                     All categories
# 14 2025-04-09 08:50:00                     All categories
# 15 2025-04-09 08:16:00                     All categories
# 16 2025-04-09 08:14:00                     All categories
# 17 2025-04-09 08:11:00                     All categories
# 18 2025-04-09 07:27:00                     All categories
# 19 2025-04-09 07:18:00                     All categories
# 20 2025-04-09 07:16:00                     All categories
# 21 2025-04-09 07:05:00                     All categories
# 22 2025-04-09 07:03:00                     All categories
# 23 2025-04-09 06:52:00                     All categories
# 24 2025-04-08 15:00:00        ECB - European Central Bank
# 25 2025-04-08 15:00:00        ECB - European Central Bank
# 26 2025-04-08 15:00:00  FRB: Press Release - All Releases
# 27 2025-04-08 15:00:00        ECB - European Central Bank
# 28 2025-04-08 12:13:10         European Banking Authority
# 29 2025-04-08 12:00:00                     All categories
# 30 2025-04-08 08:19:00                     All categories
# 31 2025-04-07 13:47:37        EBA external communications
# 32 2025-04-07 13:44:29        EBA external communications
# 33 2025-04-07 13:40:00        EBA external communications
# 34 2025-04-07 13:33:39        EBA external communications
# 35 2025-04-07 13:31:19        EBA external communications
# 36 2025-04-07 13:29:08        EBA external communications
# 37 2025-04-07 12:46:18        EBA external communications
# 38 2025-04-07 12:42:46        EBA external communications
# 39 2025-04-07 12:40:00        EBA external communications
# 40 2025-04-07 12:33:00        EBA external communications
# 41 2025-04-07 12:18:59         European Banking Authority
# 42 2025-04-07 12:00:00                     All categories
# 43 2025-04-07 09:00:00        ECB - European Central Bank
# 44 2025-04-07 08:46:00                     All categories
# 45 2025-04-07 08:42:00                     All categories
# 46 2025-04-07 08:39:00                     All categories
# 47 2025-04-07 08:07:00                     All categories
# 48 2025-04-07 08:07:00                     All categories
# 49 2025-04-07 08:02:00                     All categories
# 50 2025-04-04 12:00:00         European Banking Authority
# 51 2025-04-04 09:00:00        ECB - European Central Bank
#
#                                                           source_url
# 0                 https://www.bis.org/doclist/rss_all_categories.rss
# 1            https://www.bankingsupervision.europa.eu/rss/press.html
# 2              https://www.bankingsupervision.europa.eu/rss/pub.html
# 3            https://www.bankingsupervision.europa.eu/rss/press.html
# 5                 https://www.bis.org/doclist/rss_all_categories.rss
# 6         https://www.bankingsupervision.europa.eu/rss/speeches.html
# 8                 https://www.bis.org/doclist/rss_all_categories.rss
# 9                 https://www.federalreserve.gov/feeds/press_all.xml
# 10                https://www.bis.org/doclist/rss_all_categories.rss
# 11                https://www.bis.org/doclist/rss_all_categories.rss
# 12                          https://www.ecb.europa.eu/rss/wppub.html
# 13                https://www.bis.org/doclist/rss_all_categories.rss
# 14                https://www.bis.org/doclist/rss_all_categories.rss
# 15                https://www.bis.org/doclist/rss_all_categories.rss
# 16                https://www.bis.org/doclist/rss_all_categories.rss
# 17                https://www.bis.org/doclist/rss_all_categories.rss
# 18                https://www.bis.org/doclist/rss_all_categories.rss
# 19                https://www.bis.org/doclist/rss_all_categories.rss
# 20                https://www.bis.org/doclist/rss_all_categories.rss
# 21                https://www.bis.org/doclist/rss_all_categories.rss
# 22                https://www.bis.org/doclist/rss_all_categories.rss
# 23                https://www.bis.org/doclist/rss_all_categories.rss
# 24           https://www.bankingsupervision.europa.eu/rss/press.html
# 25           https://www.bankingsupervision.europa.eu/rss/press.html
# 26                https://www.federalreserve.gov/feeds/press_all.xml
# 27           https://www.bankingsupervision.europa.eu/rss/press.html
# 28                 https://www.eba.europa.eu/news-press/news/rss.xml
# 29                https://www.bis.org/doclist/rss_all_categories.rss
# 30                https://www.bis.org/doclist/rss_all_categories.rss
# 31  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 32  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 33  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 34  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 35  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 36  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 37  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 38  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 39  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 40  https://ec.europa.eu/newsroom/eba/feed?item_type_id=1642&lang=en
# 41                 https://www.eba.europa.eu/news-press/news/rss.xml
# 42                https://www.bis.org/doclist/rss_all_categories.rss
# 43                           https://www.ecb.europa.eu/rss/blog.html
# 44                https://www.bis.org/doclist/rss_all_categories.rss
# 45                https://www.bis.org/doclist/rss_all_categories.rss
# 46                https://www.bis.org/doclist/rss_all_categories.rss
# 47                https://www.bis.org/doclist/rss_all_categories.rss
# 48                https://www.bis.org/doclist/rss_all_categories.rss
# 49                https://www.bis.org/doclist/rss_all_categories.rss
# 50                 https://www.eba.europa.eu/news-press/news/rss.xml
# 51                      https://www.ecb.europa.eu/rss/statpress.html
