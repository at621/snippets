# %% [markdown]
# ### Basel II RWA calculations
#
# 1. The purpose of the notenook is to perform RWA calculations as described in the https://www.bis.org/publ/bcbs128.pdf
# 2. The results are tested against test cases as provided by the BIS
# 3. The maturity flooring is a simplification (see 32.51 in https://www.bis.org/basel_framework/chapter/CRE/32.htm?inforce=20230101&published=20200327)

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

# Settings
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def calculate_RWA(exposure_type, PD, LGD, EAD, add_on=1.06, M=None, S=None):
    """
    Calculate Risk-Weighted Assets (RWA) for different types of exposures.
    
    Parameters:
    - exposure_type (str): Type of regulatory exposure class.
    - PD (float): Probability of Default. Must be between 0 and 1.
    - LGD (float): Loss Given Default. Must be between 0 and 1.
    - EAD (float): Exposure at Default.
    - M (float, optional): Maturity for corporate exposures. Must be between 1 and 3. Default is None.
    - S (float, optional): Sales for SME corporate exposures. Must be between 1 and 50. Default is None.
    
    Returns:
    - float: Risk-Weighted Assets (RWA) based on the given inputs.
    
    Raises:
    - AssertionError: If PD or LGD are not between 0 and 1.
    """
    
    # Validate input ranges
    assert 0 <= PD <= 1, "PD must be between 0 and 1."
    assert 0 <= LGD <= 1, "LGD must be between 0 and 1."
    if M is not None:
        M = np.clip(M, 1, 5)
    if S is not None:
        S = np.clip(S, 5, 50)
    
    # The G function, the inverse of the standard normal cumulative distribution function
    def G(z):
        return norm.ppf(z)

    # Calculate Correlation R based on exposure type
    if exposure_type == "Residential Mortgages":
        R = 0.15
    elif exposure_type == "Qualifying Revolving Retail Exposures":
        R = 0.04
    elif exposure_type == "Other Retail Exposures":
        R = 0.03 * (1 - np.exp(-35 * PD)) / (1 - np.exp(-35)) + 0.16 * (1 - (1 - np.exp(-35 * PD)) / (1 - np.exp(-35)))
    elif exposure_type == "Corporate Exposures":
        R = 0.12 * (1 - np.exp(-50 * PD)) / (1 - np.exp(-50)) + 0.24 * (1 - (1 - np.exp(-50 * PD)) / (1 - np.exp(-50)))
        if S is not None:
            R -= 0.04 * (1 - (S - 5) / 45)
    else:
        return np.nan
    
    # Calculate Capital Requirement K
    if exposure_type == "Corporate Exposures":
        # Maturity adjustment b for corporate exposures
        b = (0.11852 - 0.05478 * np.log(PD)) ** 2
        K = (LGD * norm.cdf(np.sqrt((1 - R)**-1) * G(PD) + np.sqrt(R / (1 - R)) * G(0.999)) - PD * LGD) * (1 - 1.5 * b) ** -1 * (1 + (M - 2.5) * b)
    else:
        K = LGD * norm.cdf(((1 - R)**-0.5) * G(PD) + (R / (1 - R)) ** 0.5 * G(0.999)) - PD * LGD
    
    # Calculate Risk-Weighted Assets RWA
    RWA = K * 12.5 * EAD * add_on
    
    return RWA

# %%
# Test the function with incorrect PD and LGD values to see if assertions work
try:
    print("RWA for Corporate Exposure:", calculate_RWA("Corporate Exposures", 1.2, 0.4, 100, 3))
except AssertionError as e:
    print(e)

try:
    print("RWA for Corporate Exposure:", calculate_RWA("Corporate Exposures", 0.02, -0.4, 100, 3))
except AssertionError as e:
    print(e)

# Example usage
PD = 0.02  # Probability of Default
LGD = 0.4  # Loss Given Default
EAD = 100  # Exposure at Default
M = 3     # Maturity
S = 10    # Sales for SME
add_on = 1.06

print("RWA for Residential Mortgage:", calculate_RWA("Residential Mortgages", PD, LGD, EAD, add_on))
print("RWA for Qualifying Revolving Retail:", calculate_RWA("Qualifying Revolving Retail Exposures", PD, LGD, EAD, add_on))
print("RWA for Other Retail:", calculate_RWA("Other Retail Exposures", PD, LGD, EAD, add_on))
print("RWA for Corporate Exposure:", calculate_RWA("Corporate Exposures", PD, LGD, EAD, M, add_on))
print("RWA for SME Corporate Exposure:", calculate_RWA("Corporate Exposures", PD, LGD, EAD, M, S, add_on))
# Out:
# PD must be between 0 and 1.
# LGD must be between 0 and 1.
# RWA for Residential Mortgage: 82.85433774748495
# RWA for Qualifying Revolving Retail: 27.251803169301215
# RWA for Other Retail: 54.63611515913094
# RWA for Corporate Exposure: 257.42410788421637
# RWA for SME Corporate Exposure: 301.5092152166892

# %%
# Data provided in the Annex 5 of https://www.bis.org/publ/bcbs128.pdf
data = [
    [0.03, 14.44, 11.30, 4.15, 2.30, 4.45, 8.41, 0.98, 1.85],
    [0.05, 19.65, 15.39, 6.23, 3.46, 6.63, 12.52, 1.51, 2.86],
    [0.10, 29.65, 23.30, 10.69, 5.94, 11.16, 21.08, 2.71, 5.12],
    [0.25, 49.47, 39.01, 21.30, 11.83, 21.15, 39.96, 5.76, 10.88],
    [0.40, 62.72, 49.49, 29.94, 16.64, 28.42, 53.69, 8.41, 15.88],
    [0.50, 69.61, 54.91, 35.08, 19.49, 32.36, 61.13, 10.04, 18.97],
    [0.75, 82.78, 65.14, 46.46, 25.81, 40.10, 75.74, 13.80, 26.06],
    [1.00, 92.32, 72.40, 56.40, 31.33, 45.77, 86.46, 17.22, 32.53],
    [1.30, 100.95, 78.77, 67.00, 37.22, 50.80, 95.95, 21.02, 39.70],
    [1.50, 105.59, 82.11, 73.45, 40.80, 53.37, 100.81, 23.40, 44.19],
    [2.00, 114.86, 88.55, 87.94, 48.85, 57.99, 109.53, 28.92, 54.63],
    [2.50, 122.16, 93.43, 100.64, 55.91, 60.90, 115.03, 33.98, 64.18],
    [3.00, 128.44, 97.58, 111.99, 62.22, 62.79, 118.61, 38.66, 73.03],
    [4.00, 139.58, 105.04, 131.63, 73.13, 65.01, 122.80, 47.16, 89.08],
    [5.00, 149.86, 112.27, 148.22, 82.35, 66.42, 125.45, 54.75, 103.41],
    [6.00, 159.61, 119.48, 162.52, 90.29, 67.73, 127.94, 61.61, 116.37],
    [10.00, 193.09, 146.51, 204.41, 113.56, 75.54, 142.69, 83.89, 158.47],
    [15.00, 221.54, 171.91, 235.72, 130.96, 88.60, 167.36, 103.89, 196.23],
    [20.00, 238.23, 188.42, 253.12, 140.62, 100.28, 189.41, 117.99, 222.86]
]

# Dummy 3-level column names
columns = pd.MultiIndex.from_tuples([
    ('PD', '', ''),
    ('Corporate Exposures', 0.45, 50),
    ('Corporate Exposures', 0.45, 5),
    ('Residential Mortgages', 0.45, 0),
    ('Residential Mortgages', 0.25, 0),
    ('Other Retail Exposures', 0.45, 0),
    ('Other Retail Exposures', 0.85, 0),
    ('Qualifying Revolving Retail Exposures', 0.45, 0),
    ('Qualifying Revolving Retail Exposures', 0.85, 0),
], names=['Segment', 'LGD', 'SME'])

# Create the original DataFrame again
df = pd.DataFrame(data, columns=columns)

# Set 'PD' as index for stacking
df['PD'] = df[('PD', '', '')]
df_dropped = df.drop(('PD', '', ''), axis=1)
df_dropped = df_dropped.set_index(df['PD'])

# Perform the stack operation
df_stacked = df_dropped.stack(level=[0, 1, 2]).reset_index(name='Value')
df_stacked.columns = ['PD', 'Segment', 'LGD', 'SME', 'Value']

# Applying the function row-wise
bis_add_on = 1.0
df_stacked['RWA_calc'] = df_stacked.apply(lambda row: calculate_RWA(row['Segment'], 
                                                                    row['PD'] / 100, 
                                                                    row['LGD'], 
                                                                    100, 
                                                                    bis_add_on,
                                                                    2.5, 
                                                                    row['SME'],
                                                                    ), axis=1)

df_stacked['RWA_calc'] = df_stacked['RWA_calc'].round(3)
df_stacked['diff'] = abs(1- df_stacked['RWA_calc'] / df_stacked['Value'])
df_stacked.head(70)
# Out:
#       PD                                Segment   LGD  SME   Value  RWA_calc  \
# 0   0.03                    Corporate Exposures  0.45    5   11.30    11.299
# 1   0.03                    Corporate Exposures  0.45   50   14.44    14.444
# 2   0.03                 Other Retail Exposures  0.45    0    4.45     4.451
# 3   0.03                 Other Retail Exposures  0.85    0    8.41     8.408
# 4   0.03  Qualifying Revolving Retail Exposures  0.45    0    0.98     0.980
# 5   0.03  Qualifying Revolving Retail Exposures  0.85    0    1.85     1.851
# 6   0.03                  Residential Mortgages  0.25    0    2.30     2.305
# 7   0.03                  Residential Mortgages  0.45    0    4.15     4.149
# 8   0.05                    Corporate Exposures  0.45    5   15.39    15.396
# 9   0.05                    Corporate Exposures  0.45   50   19.65    19.651
# 10  0.05                 Other Retail Exposures  0.45    0    6.63     6.629
# 11  0.05                 Other Retail Exposures  0.85    0   12.52    12.522
# 12  0.05  Qualifying Revolving Retail Exposures  0.45    0    1.51     1.513
# 13  0.05  Qualifying Revolving Retail Exposures  0.85    0    2.86     2.858
# 14  0.05                  Residential Mortgages  0.25    0    3.46     3.461
# 15  0.05                  Residential Mortgages  0.45    0    6.23     6.230
# 16  0.10                    Corporate Exposures  0.45    5   23.30    23.297
# 17  0.10                    Corporate Exposures  0.45   50   29.65    29.654
# 18  0.10                 Other Retail Exposures  0.45    0   11.16    11.163
# 19  0.10                 Other Retail Exposures  0.85    0   21.08    21.086
# 20  0.10  Qualifying Revolving Retail Exposures  0.45    0    2.71     2.709
# 21  0.10  Qualifying Revolving Retail Exposures  0.85    0    5.12     5.116
# 22  0.10                  Residential Mortgages  0.25    0    5.94     5.939
# 23  0.10                  Residential Mortgages  0.45    0   10.69    10.690
# 24  0.25                    Corporate Exposures  0.45    5   39.01    39.010
# 25  0.25                    Corporate Exposures  0.45   50   49.47    49.472
# 26  0.25                 Other Retail Exposures  0.45    0   21.15    21.154
# 27  0.25                 Other Retail Exposures  0.85    0   39.96    39.958
# 28  0.25  Qualifying Revolving Retail Exposures  0.45    0    5.76     5.759
# 29  0.25  Qualifying Revolving Retail Exposures  0.85    0   10.88    10.877
# 30  0.25                  Residential Mortgages  0.25    0   11.83    11.832
# 31  0.25                  Residential Mortgages  0.45    0   21.30    21.297
# 32  0.40                    Corporate Exposures  0.45    5   49.49    49.490
# 33  0.40                    Corporate Exposures  0.45   50   62.72    62.718
# 34  0.40                 Other Retail Exposures  0.45    0   28.42    28.424
# 35  0.40                 Other Retail Exposures  0.85    0   53.69    53.689
# 36  0.40  Qualifying Revolving Retail Exposures  0.45    0    8.41     8.409
# 37  0.40  Qualifying Revolving Retail Exposures  0.85    0   15.88    15.883
# 38  0.40                  Residential Mortgages  0.25    0   16.64    16.636
# 39  0.40                  Residential Mortgages  0.45    0   29.94    29.945
# 40  0.50                    Corporate Exposures  0.45    5   54.91    54.911
# 41  0.50                    Corporate Exposures  0.45   50   69.61    69.612
# 42  0.50                 Other Retail Exposures  0.45    0   32.36    32.361
# 43  0.50                 Other Retail Exposures  0.85    0   61.13    61.127
# 44  0.50  Qualifying Revolving Retail Exposures  0.45    0   10.04    10.041
# 45  0.50  Qualifying Revolving Retail Exposures  0.85    0   18.97    18.966
# 46  0.50                  Residential Mortgages  0.25    0   19.49    19.488
# 47  0.50                  Residential Mortgages  0.45    0   35.08    35.079
# 48  0.75                    Corporate Exposures  0.45    5   65.14    65.144
# 49  0.75                    Corporate Exposures  0.45   50   82.78    82.778
# 50  0.75                 Other Retail Exposures  0.45    0   40.10    40.098
# 51  0.75                 Other Retail Exposures  0.85    0   75.74    75.741
# 52  0.75  Qualifying Revolving Retail Exposures  0.45    0   13.80    13.799
# 53  0.75  Qualifying Revolving Retail Exposures  0.85    0   26.06    26.064
# 54  0.75                  Residential Mortgages  0.25    0   25.81    25.813
# 55  0.75                  Residential Mortgages  0.45    0   46.46    46.464
# 56  1.00                    Corporate Exposures  0.45    5   72.40    72.395
# 57  1.00                    Corporate Exposures  0.45   50   92.32    92.317
# 58  1.00                 Other Retail Exposures  0.45    0   45.77    45.773
# 59  1.00                 Other Retail Exposures  0.85    0   86.46    86.460
# 60  1.00  Qualifying Revolving Retail Exposures  0.45    0   17.22    17.224
# 61  1.00  Qualifying Revolving Retail Exposures  0.85    0   32.53    32.535
# 62  1.00                  Residential Mortgages  0.25    0   31.33    31.333
# 63  1.00                  Residential Mortgages  0.45    0   56.40    56.399
# 64  1.30                    Corporate Exposures  0.45    5   78.77    78.772
# 65  1.30                    Corporate Exposures  0.45   50  100.95   100.947
# 66  1.30                 Other Retail Exposures  0.45    0   50.80    50.794
# 67  1.30                 Other Retail Exposures  0.85    0   95.95    95.945
# 68  1.30  Qualifying Revolving Retail Exposures  0.45    0   21.02    21.018
# 69  1.30  Qualifying Revolving Retail Exposures  0.85    0   39.70    39.700
#
#         diff
# 0   0.000088
# 1   0.000277
# 2   0.000225
# 3   0.000238
# 4   0.000000
# 5   0.000541
# 6   0.002174
# 7   0.000241
# 8   0.000390
# 9   0.000051
# 10  0.000151
# 11  0.000160
# 12  0.001987
# 13  0.000699
# 14  0.000289
# 15  0.000000
# 16  0.000129
# 17  0.000135
# 18  0.000269
# 19  0.000285
# 20  0.000369
# 21  0.000781
# 22  0.000168
# 23  0.000000
# 24  0.000000
# 25  0.000040
# 26  0.000189
# 27  0.000050
# 28  0.000174
# 29  0.000276
# 30  0.000169
# 31  0.000141
# 32  0.000000
# 33  0.000032
# 34  0.000141
# 35  0.000019
# 36  0.000119
# 37  0.000189
# 38  0.000240
# 39  0.000167
# 40  0.000018
# 41  0.000029
# 42  0.000031
# 43  0.000049
# 44  0.000100
# 45  0.000211
# 46  0.000103
# 47  0.000029
# 48  0.000061
# 49  0.000024
# 50  0.000050
# 51  0.000013
# 52  0.000072
# 53  0.000153
# 54  0.000116
# 55  0.000086
# 56  0.000069
# 57  0.000032
# 58  0.000066
# 59  0.000000
# 60  0.000232
# 61  0.000154
# 62  0.000096
# 63  0.000018
# 64  0.000025
# 65  0.000030
# 66  0.000118
# 67  0.000052
# 68  0.000095
# 69  0.000000

# %%
print(f"The maximum difference between calculated and provided RW is {df_stacked['diff'].max():.2%}")
# Out:
# The maximum difference between calculated and provided RW is 0.22%
