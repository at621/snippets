# %%
import pandas as pd
import matplotlib
from io import StringIO

# 1) Load the CSV data, set "Country" as index, and convert to decimal fractions:
csv_data = """
Country,2009,2010,2011,2012,2013,2015,2016,2017,2018,2019,2020,2021
Austria,1.025,1.040,1.215,1.449,1.881,0.878,0.762,1.954,0.952,0.650,1.289,0.286
Belgium,1.083,1.119,2.768,1.991,1.737,1.500,1.235,0.762,1.138,1.461,1.529,1.344
Denmark,1.890,1.690,1.467,1.817,1.702,1.089,1.085,0.662,0.604,0.595,0.692,0.501
France,1.109,1.017,0.808,1.366,1.248,0.587,0.721,0.583,0.767,1.086,0.880,0.635
Germany,1.421,1.197,1.235,1.468,1.663,1.339,1.426,1.003,1.011,0.838,0.752,0.445
Ireland,7.786,10.142,16.884,16.988,10.462,2.918,2.185,1.996,2.839,3.821,1.878,1.989
Italy,3.240,2.134,3.474,5.212,6.838,3.571,1.877,6.903,5.374,1.378,0.687,0.670
Luxembourg,8.130,1.049,1.445,5.409,7.379,0.599,1.665,0.784,0.483,0.416,0.992,0.468
Netherlands,1.611,2.174,1.787,2.502,3.752,2.315,1.547,2.322,1.700,1.734,1.530,0.888
Norway,0.878,0.986,1.013,1.395,0.520,0.950,1.452,1.447,1.468,1.220,1.823,1.448
Poland,5.379,3.797,2.608,3.643,3.183,0.898,0.980,1.147,0.859,1.523,0.791,0.962
Portugal,2.598,2.005,5.247,7.104,5.975,11.790,5.881,3.115,2.743,1.598,1.511,2.083
Spain,5.004,4.042,3.539,6.697,8.560,5.234,3.827,3.184,2.062,1.824,1.380,3.118
Sweden,0.678,0.454,0.181,0.338,0.342,0.303,0.257,0.177,0.168,0.332,0.250,0.065
United Kingdom,1.423,1.071,2.509,1.996,2.379,0.768,1.025,1.237,0.887,1.267,1.165,1.384
"""
df = pd.read_csv(StringIO(csv_data)).set_index('Country')
df /= 100  # Convert percentages to decimal (e.g., 1.025% -> 0.01025)

# 2) Reset index to make "Country" a normal column
df_reset = df.reset_index()

# 3) Create a row of average values
numeric_cols = df_reset.select_dtypes(include='number').columns
mean_vals = df_reset[numeric_cols].mean()
avg_row = pd.DataFrame([["Average"] + list(mean_vals)], columns=df_reset.columns)
df_with_avg = pd.concat([df_reset, avg_row], ignore_index=True)

# 4) Compute per-row "Max DF" and "Mean DF"
df_with_avg["Max DF"] = df_with_avg[numeric_cols].max(axis=1)
df_with_avg["Mean DF"] = df_with_avg[numeric_cols].mean(axis=1)

# Update numeric_cols (since we added two new columns)
numeric_cols = df_with_avg.select_dtypes(include='number').columns

# 5) Define a color gradient function for each row
def highlight_row(row):
    vals = row[numeric_cols]
    norm = matplotlib.colors.TwoSlopeNorm(
        vcenter=vals.mean(),
        vmin=vals.min(),
        vmax=vals.max()
    )
    cmap = matplotlib.colormaps.get_cmap('RdYlGn_r')
    styles = []
    for col in row.index:
        if col in numeric_cols:
            r, g, b, _ = cmap(norm(row[col]))
            styles.append(f'background-color: {matplotlib.colors.to_hex((r, g, b, 0.4), keep_alpha=True)}')
        else:
            styles.append('')
    return styles

# 6) Apply styling
styled = (
    df_with_avg
    .style
    .format("{:.2%}", subset=numeric_cols)  # Format numeric columns as % with 2 decimals
    .apply(highlight_row, axis=1)          # Apply gradient row-wise
    .set_properties(subset=numeric_cols, **{"color": "black"})
    .set_table_styles([
        {"selector": "table",                   "props": [("border-collapse", "collapse"), ("border", "none")]},
        {"selector": "th",                      "props": [("border", "none")]},
        {"selector": "td",                      "props": [("border", "none")]},
        {"selector": "tbody tr:last-child td",  "props": [("font-weight", "bold")]}  # Make last row bold
    ])
)

styled
# Out:
# <style type="text/css">
# #T_42534 table {
#   border-collapse: collapse;
#   border: none;
# }
# #T_42534 th {
#   border: none;
# }
# #T_42534 td {
#   border: none;
# }
# #T_42534 tbody tr:last-child td {
#   font-weight: bold;
# }
# #T_42534_row0_col1, #T_42534_row2_col7, #T_42534_row7_col14 {
#   background-color: #dff29366;
#   color: black;
# }
# #T_42534_row0_col2, #T_42534_row3_col11, #T_42534_row6_col1 {
#   background-color: #e2f39766;
#   color: black;
# }
# #T_42534_row0_col3, #T_42534_row13_col5 {
#   background-color: #fff7b266;
#   color: black;
# }
# #T_42534_row0_col4, #T_42534_row1_col4, #T_42534_row3_col10 {
#   background-color: #fdb96a66;
#   color: black;
# }
# #T_42534_row0_col5 {
#   background-color: #bb152666;
#   color: black;
# }
# #T_42534_row0_col6, #T_42534_row9_col3 {
#   background-color: #b7e07566;
#   color: black;
# }
# #T_42534_row0_col7, #T_42534_row8_col7 {
#   background-color: #91d06866;
#   color: black;
# }
# #T_42534_row0_col8, #T_42534_row0_col13, #T_42534_row1_col3, #T_42534_row1_col13, #T_42534_row2_col1, #T_42534_row2_col13, #T_42534_row3_col4, #T_42534_row3_col13, #T_42534_row4_col5, #T_42534_row4_col13, #T_42534_row5_col4, #T_42534_row5_col13, #T_42534_row6_col8, #T_42534_row6_col13, #T_42534_row7_col1, #T_42534_row7_col13, #T_42534_row8_col5, #T_42534_row8_col13, #T_42534_row9_col11, #T_42534_row9_col13, #T_42534_row10_col1, #T_42534_row10_col13, #T_42534_row11_col6, #T_42534_row11_col13, #T_42534_row12_col5, #T_42534_row12_col13, #T_42534_row13_col1, #T_42534_row13_col13, #T_42534_row14_col3, #T_42534_row14_col13, #T_42534_row15_col4, #T_42534_row15_col13 {
#   background-color: #a5002666;
#   color: black;
# }
# #T_42534_row0_col9, #T_42534_row13_col7 {
#   background-color: #cbe98266;
#   color: black;
# }
# #T_42534_row0_col10, #T_42534_row4_col11, #T_42534_row14_col2 {
#   background-color: #69be6366;
#   color: black;
# }
# #T_42534_row0_col11, #T_42534_row1_col5 {
#   background-color: #fee99966;
#   color: black;
# }
# #T_42534_row0_col12, #T_42534_row1_col8, #T_42534_row2_col12, #T_42534_row3_col8, #T_42534_row4_col12, #T_42534_row5_col11, #T_42534_row6_col11, #T_42534_row6_col12, #T_42534_row7_col10, #T_42534_row8_col12, #T_42534_row9_col5, #T_42534_row10_col11, #T_42534_row11_col11, #T_42534_row12_col11, #T_42534_row13_col12, #T_42534_row14_col6, #T_42534_row15_col12 {
#   background-color: #00683766;
#   color: black;
# }
# #T_42534_row0_col14 {
#   background-color: #f2faae66;
#   color: black;
# }
# #T_42534_row1_col1, #T_42534_row6_col7, #T_42534_row13_col9 {
#   background-color: #66bd6366;
#   color: black;
# }
# #T_42534_row1_col2 {
#   background-color: #73c26466;
#   color: black;
# }
# #T_42534_row1_col6, #T_42534_row6_col14, #T_42534_row15_col2 {
#   background-color: #eff8aa66;
#   color: black;
# }
# #T_42534_row1_col7, #T_42534_row8_col1 {
#   background-color: #a2d76a66;
#   color: black;
# }
# #T_42534_row1_col9, #T_42534_row10_col10 {
#   background-color: #7ac66566;
#   color: black;
# }
# #T_42534_row1_col10 {
#   background-color: #e6f59d66;
#   color: black;
# }
# #T_42534_row1_col11, #T_42534_row6_col6, #T_42534_row15_col6 {
#   background-color: #f7fcb466;
#   color: black;
# }
# #T_42534_row1_col12, #T_42534_row12_col3 {
#   background-color: #c5e67e66;
#   color: black;
# }
# #T_42534_row1_col14 {
#   background-color: #e9f6a166;
#   color: black;
# }
# #T_42534_row2_col2 {
#   background-color: #e44c3466;
#   color: black;
# }
# #T_42534_row2_col3 {
#   background-color: #fdb16366;
#   color: black;
# }
# #T_42534_row2_col4 {
#   background-color: #be182766;
#   color: black;
# }
# #T_42534_row2_col5, #T_42534_row3_col5 {
#   background-color: #e1443066;
#   color: black;
# }
# #T_42534_row2_col6, #T_42534_row11_col14, #T_42534_row14_col12 {
#   background-color: #e0f29566;
#   color: black;
# }
# #T_42534_row2_col8, #T_42534_row6_col10, #T_42534_row12_col9 {
#   background-color: #249d5366;
#   color: black;
# }
# #T_42534_row2_col9, #T_42534_row3_col12 {
#   background-color: #128a4966;
#   color: black;
# }
# #T_42534_row2_col10 {
#   background-color: #11884866;
#   color: black;
# }
# #T_42534_row2_col11 {
#   background-color: #33a45666;
#   color: black;
# }
# #T_42534_row2_col14, #T_42534_row6_col3, #T_42534_row13_col6 {
#   background-color: #f1f9ac66;
#   color: black;
# }
# #T_42534_row3_col1 {
#   background-color: #fdad6066;
#   color: black;
# }
# #T_42534_row3_col2 {
#   background-color: #fee18d66;
#   color: black;
# }
# #T_42534_row3_col3 {
#   background-color: #b1de7166;
#   color: black;
# }
# #T_42534_row3_col6 {
#   background-color: #016a3866;
#   color: black;
# }
# #T_42534_row3_col7 {
#   background-color: #63bc6266;
#   color: black;
# }
# #T_42534_row3_col9, #T_42534_row4_col10, #T_42534_row8_col11 {
#   background-color: #8ecf6766;
#   color: black;
# }
# #T_42534_row3_col14, #T_42534_row15_col14 {
#   background-color: #ecf7a666;
#   color: black;
# }
# #T_42534_row4_col1, #T_42534_row7_col4, #T_42534_row14_col4 {
#   background-color: #f9915366;
#   color: black;
# }
# #T_42534_row4_col2 {
#   background-color: #fffcba66;
#   color: black;
# }
# #T_42534_row4_col3 {
#   background-color: #feefa366;
#   color: black;
# }
# #T_42534_row4_col4 {
#   background-color: #f4704466;
#   color: black;
# }
# #T_42534_row4_col6, #T_42534_row5_col5 {
#   background-color: #fdc37266;
#   color: black;
# }
# #T_42534_row4_col7 {
#   background-color: #f88c5166;
#   color: black;
# }
# #T_42534_row4_col8 {
#   background-color: #cdea8366;
#   color: black;
# }
# #T_42534_row4_col9 {
#   background-color: #cfeb8566;
#   color: black;
# }
# #T_42534_row4_col14, #T_42534_row9_col10 {
#   background-color: #f5fbb266;
#   color: black;
# }
# #T_42534_row5_col1, #T_42534_row13_col4 {
#   background-color: #fff8b466;
#   color: black;
# }
# #T_42534_row5_col2 {
#   background-color: #feca7966;
#   color: black;
# }
# #T_42534_row5_col3 {
#   background-color: #a7022666;
#   color: black;
# }
# #T_42534_row5_col6 {
#   background-color: #18954f66;
#   color: black;
# }
# #T_42534_row5_col7 {
#   background-color: #07753e66;
#   color: black;
# }
# #T_42534_row5_col8, #T_42534_row5_col12, #T_42534_row7_col12 {
#   background-color: #026c3966;
#   color: black;
# }
# #T_42534_row5_col9, #T_42534_row11_col12, #T_42534_row15_col10 {
#   background-color: #16914d66;
#   color: black;
# }
# #T_42534_row5_col10 {
#   background-color: #54b45f66;
#   color: black;
# }
# #T_42534_row5_col14 {
#   background-color: #e5f49b66;
#   color: black;
# }
# #T_42534_row6_col2, #T_42534_row9_col1, #T_42534_row11_col8 {
#   background-color: #7fc86666;
#   color: black;
# }
# #T_42534_row6_col4, #T_42534_row10_col2 {
#   background-color: #fa965666;
#   color: black;
# }
# #T_42534_row6_col5 {
#   background-color: #a9042666;
#   color: black;
# }
# #T_42534_row6_col9 {
#   background-color: #f7844e66;
#   color: black;
# }
# #T_42534_row7_col2 {
#   background-color: #30a35666;
#   color: black;
# }
# #T_42534_row7_col3, #T_42534_row13_col8 {
#   background-color: #70c16466;
#   color: black;
# }
# #T_42534_row7_col5 {
#   background-color: #c8222766;
#   color: black;
# }
# #T_42534_row7_col6 {
#   background-color: #09794066;
#   color: black;
# }
# #T_42534_row7_col7 {
#   background-color: #8ccd6766;
#   color: black;
# }
# #T_42534_row7_col8, #T_42534_row11_col2, #T_42534_row12_col10 {
#   background-color: #138c4a66;
#   color: black;
# }
# #T_42534_row7_col9, #T_42534_row11_col10 {
#   background-color: #036e3a66;
#   color: black;
# }
# #T_42534_row7_col11 {
#   background-color: #279f5366;
#   color: black;
# }
# #T_42534_row8_col2 {
#   background-color: #fffab666;
#   color: black;
# }
# #T_42534_row8_col3 {
#   background-color: #c7e77f66;
#   color: black;
# }
# #T_42534_row8_col4, #T_42534_row9_col4 {
#   background-color: #fed68366;
#   color: black;
# }
# #T_42534_row8_col6 {
#   background-color: #feec9f66;
#   color: black;
# }
# #T_42534_row8_col8 {
#   background-color: #feeb9d66;
#   color: black;
# }
# #T_42534_row8_col9 {
#   background-color: #b5df7466;
#   color: black;
# }
# #T_42534_row8_col10 {
#   background-color: #bde37966;
#   color: black;
# }
# #T_42534_row8_col14, #T_42534_row12_col2, #T_42534_row12_col14, #T_42534_row13_col14, #T_42534_row14_col1, #T_42534_row14_col14 {
#   background-color: #ebf7a366;
#   color: black;
# }
# #T_42534_row9_col2 {
#   background-color: #addc6f66;
#   color: black;
# }
# #T_42534_row9_col6, #T_42534_row12_col12 {
#   background-color: #a0d66966;
#   color: black;
# }
# #T_42534_row9_col7 {
#   background-color: #fdbd6d66;
#   color: black;
# }
# #T_42534_row9
