# %% [markdown]
# ### Size of the github repo

# %%
import subprocess
import os
import pandas as pd

# Settings
pd.set_option('display.max_colwidth', None)

# %%
# The URL of your specific repository
repo_url = 'https://github.com/guillermo-navas-palencia/optbinning.git'
repo_name = repo_url.split('/')[-1].replace('.git', '')

# List to hold file information
files_data = []

# Walk through the repository directory
for root, dirs, files in os.walk(repo_name):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            # Determine the file's category
            if ".git" in file_path:
                category = "Git-related"
            elif file_path.endswith('.py'):
                category = "Python"
            elif file_path.endswith('.ipynb'):
                category = "Jupyter Notebook"
            else:
                category = "Other"

            # Count lines in each file
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                line_count = sum(1 for line in f)

            # Extract directory name and file name
            directory_name = os.path.relpath(root, repo_name)
            files_data.append({
                "Directory": directory_name,
                "File Name": file,
                "Line Count": line_count,
                "Category": category
            })
        except Exception as e:
            print(f"Error reading {file_path}: {e}")

# Create a pandas DataFrame
df = pd.DataFrame(files_data)

# Summing line counts by category
df.groupby('Category').agg({'File Name': ['count'], \
                            'Line Count': ['sum']}).reset_index()
# Out:
#            Category File Name Line Count
#                         count        sum
# 0       Git-related        28      86819
# 1  Jupyter Notebook        20      36464
# 2             Other        70      20318
# 3            Python       100      31174

# %%
df.sort_values('Line Count', ascending=False).head(20).reset_index()
# Out:
#     index             Directory  \
# 0      30     .git\objects\pack
# 1      84    doc\source\_images
# 2      63  doc\source\tutorials
# 3      59  doc\source\tutorials
# 4      62  doc\source\tutorials
# 5      68  doc\source\tutorials
# 6      70  doc\source\tutorials
# 7      77  doc\source\tutorials
# 8     104    optbinning\binning
# 9      73  doc\source\tutorials
# 10     78  doc\source\tutorials
# 11    188            tests\data
# 12     72  doc\source\tutorials
# 13     69  doc\source\tutorials
# 14     67  doc\source\tutorials
# 15    102    optbinning\binning
# 16     74  doc\source\tutorials
# 17    100    optbinning\binning
# 18     65  doc\source\tutorials
# 19     75  doc\source\tutorials
#
#                                              File Name  Line Count  \
# 0   pack-75c2c9b8daa2b9bdb4a453998b20a9ac78ae3ecf.pack       84714
# 1                              binning_data_stream.gif        8737
# 2                            tutorial_binning_2d.ipynb        4964
# 3                                tutorial_binary.ipynb        3794
# 4              tutorial_binary_under_uncertainty.ipynb        3762
# 5                            tutorial_continuous.ipynb        2882
# 6          tutorial_counterfactual_binary_target.ipynb        2358
# 7                  tutorial_scorecard_monitoring.ipynb        2112
# 8                                binning_statistics.py        2089
# 9                      tutorial_piecewise_binary.ipynb        2044
# 10                        tutorial_sketch_binary.ipynb        1763
# 11                               breast_cancer.parquet        1683
# 12                           tutorial_multiclass.ipynb        1659
# 13                        tutorial_continuous_2d.ipynb        1575
# 14          tutorial_binning_process_telco_churn.ipynb        1557
# 15                                  binning_process.py        1550
# 16                 tutorial_piecewise_continuous.ipynb        1326
# 17                                          binning.py        1234
# 18             tutorial_binning_process_FICO_xAI.ipynb        1191
# 19              tutorial_scorecard_binary_target.ipynb        1151
#
#             Category
# 0        Git-related
# 1              Other
# 2   Jupyter Notebook
# 3   Jupyter Notebook
# 4   Jupyter Notebook
# 5   Jupyter Notebook
# 6   Jupyter Notebook
# 7   Jupyter Notebook
# 8             Python
# 9   Jupyter Notebook
# 10  Jupyter Notebook
# 11             Other
# 12  Jupyter Notebook
# 13  Jupyter Notebook
# 14  Jupyter Notebook
# 15            Python
# 16  Jupyter Notebook
# 17            Python
# 18  Jupyter Notebook
# 19  Jupyter Notebook
